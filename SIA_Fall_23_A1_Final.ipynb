# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamda202201597/AAT/blob/main/SIA_Fall_23_A1_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Statistical Intuitions and Applications
#
# ## Assignment - 1 ##

# %% [markdown]
# **Main Setup.**
# For this assignment you will select a random sample from a dataset using the codes given below with all the detailed steps. To select your random sample and save your data set on your computer follow these instructions:
#
# 1. Run the Sample size code below to find the sample size 'n' on which you will work.
# 2. Go the 3rd line of CSV file code below and enter your sample size n = ???
# 3. Now go the 4th line: df.to_csv(r'**Path where you want to store the exported CSV file\FileName.csv**')
# 3. Change **Path where you want to store the exported CSV file** to where you want to store your data.
# 4. Change **File Name** to your first name.
# 5. Run the code.
#
# Once you run these two codes, your CSV file will be saved on your device at the same location you provided. Using the third code "Access the file ..." below, you will acces this file. **Also include this CSV file in your assignment submission!**
#
# Don't run the first two codes over and over again, once you have formally started working on your assignment.

# %%
# Sample size
#import random
#s=random.randint(51,81)
#print("Sample size = n =", s)
# Out:
# Sample size = n = 66

# %%
# CSV File
#import pandas as pd
#original_data = pd.read_csv("https://raw.githubusercontent.com/zu-math/SIA-Fall-2023-Dataset/main/mod_mea_f.csv")
#df1=original_data.sample(66)  # Add your sample size here
#df1.to_csv(r'hamda almansoori.csv')

# %% [markdown]
# **Note: If you have successfully run above codes then a CSV file is already generated in your device at the same location which can be accessed using code below.**
#
# Once you have started working on the assignment, it is highly recommended not to run above codes as it will generate new "CSV File" which will give different answers. The codes below will work each time you open the assignment without the need to run above codes.

# %%
# Access the file and have a look at the dataset
import pandas as pd
df = pd.read_csv(r'hamda almansoori.csv')
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip()
df.head()
# Out:
#             Academic_Year Institution_Type_EN Campus_Zone_EN LocalFlag_EN  \
# Unnamed: 0
# 64                   2014         Non-Federal          Dubai        Expat
# 53                   2014             Federal      Abu Dhabi        Local
# 177                  2017             Federal       Fujairah        Local
# 387                  2021         Non-Federal          Ajman        Local
# 119                  2015         Non-Federal        Sharjah        Local
#
#            Gender_EN  Bachelors  Certificate  Diploma  Doctorate  \
# Unnamed: 0
# 64              Male        891            1       68          8
# 53            Female          1           19       55          8
# 177             Male         47            6        8          8
# 387           Female        411           19        6          8
# 119             Male        356           19       11          5
#
#             Graduate Diploma  Higher Diploma  Masters  Total
# Unnamed: 0
# ...

# %% [markdown]
# ## Question 1

# %% [markdown]
# Your first task is to briefly introduce the study and all the main variables in it using a brief report with clear wordings. Identify all the variables in the dataset. Explain what will you be analyzing in this report to the readers.

# %% [markdown]
# **Answer 1.**

# %% [markdown]
# our study takes into account 66 students, with the main variables being academic year, institution type, campus zone,
# local flag, gender, bachelors, certificates, diploma, doctorate, graduate diploma, higher diploma, and masters.We will be using
# real-world data from Dubai to explore different aspects of student archive. We will use statistical tools to analyze the data and
# answer specific questions about Dubai.

# %% [markdown]
# ## Question 2

# %% [markdown]
# In this task, you will generate descriptive statistics for all the quantitative variables in the dataset using the histograms and describe their distributions in terms of shape, center, spread, and presence of outliers. The codes below will provide you the histogram and five-number summary of the relevant column. You need to replace '???' with column name.

# %%
import matplotlib.pyplot as plt
df['Academic_Year'].describe()  #Change column name                       #this is for five-number summary
plt.hist(df['Academic_Year'], edgecolor='k') #Change column name          #for histogram
# Out:
# (array([28., 32.,  2.,  2.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  40.5,  80. , 119.5, 159. , 198.5, 238. , 277.5, 317. ,
#         356.5, 396. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Upon looking at the graph the shape looks to be right skewed ( positively skewd ). The range starts at 0 and ends close to 200 , and has one outlier between 350 and 400. The center has a mean between 50 and 100 and the mode is between 40 and 80, with the median being 198,5.

# %%
df['Bachelors'].describe()  #Change column name                       #this is for five-number summary
plt.hist(df['Bachelors'], edgecolor='k') #Change column name
# Out:
# (array([44.,  9.,  7.,  2.,  2.,  1.,  0.,  0.,  0.,  1.]),
#  array([1.0000e+00, 3.5360e+02, 7.0620e+02, 1.0588e+03, 1.4114e+03,
#         1.7640e+03, 2.1166e+03, 2.4692e+03, 2.8218e+03, 3.1744e+03,
#         3.5270e+03]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Upon looking at the graph the shape looks to be right skewed ( positively skewd ). The range starts at 0 and ends between 2000 and 2500 , and has one outlier between 3100 and ends a little bit after 3500. The center has a mean between 0 and 500 and the mode is between 0 and approximatly at 300, with the median being 2116.

# %%
df['Certificate'].describe()  #Change column name                       #this is for five-number summary
plt.hist(df['Certificate'], edgecolor='k') #Change column name          #for histogram
# Out:
# (array([ 6., 15.,  0.,  0., 43.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 1. ,  4.9,  8.8, 12.7, 16.6, 20.5, 24.4, 28.3, 32.2, 36.1, 40. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Upon looking at the graph the shape looks to be normal/symmetric distribution. The range starts at 16 and ends close to 20.5 , and has outliers at between 0 and 5, and another at 35 to 40. The center has a mean is between 15 and 20, and the mode looks to be between 16 and 21, with the median being 20.5.

# %%
df['Diploma'].describe()  #Change column name                       #this is for five-number summary
plt.hist(df['Diploma'], edgecolor='k') #Change column name          #for histogram
# Out:
# (array([28., 32.,  2.,  2.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  40.5,  80. , 119.5, 159. , 198.5, 238. , 277.5, 317. ,
#         356.5, 396. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Upon looking at the graph the shape looks to be right skewed ( positively skewd ). The range starts at 0 and ends close to 200 , and has one outlier between 350 and 400. The center has a mean between 50 and 100 and the mode is between 40 and 80, with the median being 198.5.

# %%
df['Doctorate'].describe()  #Change column name                       #this is for five-number summary
plt.hist(df['Doctorate'], edgecolor='k') #Change column name          #for histogram
# Out:
# (array([ 2.,  2.,  5.,  0.,  1., 49.,  0.,  4.,  0.,  3.]),
#  array([ 1. ,  2.4,  3.8,  5.2,  6.6,  8. ,  9.4, 10.8, 12.2, 13.6, 15. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Upon looking at the graph the shape looks to be normal/symmetric distribution. The range starts at 8 and ends at about 9 , and has outliers 10.8 till 12.2 and at 13.6 till 15. The center has a mean between 8 and 10 and the mode is between 8 and 9.4, with the median being 8.

# %%
df['Graduate Diploma'].describe()  #Change column name                       #this is for five-number summary
plt.hist(df['Graduate Diploma'], edgecolor='k') #Change column name          #for histogram
# Out:
# (array([16.,  2.,  0., 46.,  0.,  0.,  1.,  0.,  0.,  1.]),
#  array([  1. ,  26.1,  51.2,  76.3, 101.4, 126.5, 151.6, 176.7, 201.8,
#         226.9, 252. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Upon looking at the graph the shape looks to be slightly right skewed ( positively skewd ). The range starts between 50 and ends a little bit after 100, and has outliers at 151 to 176, and another at 226 and 252. The center has a mean between 0 and 100 and the mode and median are all the same.

# %%
df['Higher Diploma'].describe()  #Change column name                       #this is for five-number summary
plt.hist(df['Higher Diploma'], edgecolor='k') #Change column name          #for histogram
# Out:
# (array([11.,  2.,  1.,  0., 50.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 1. , 10.1, 19.2, 28.3, 37.4, 46.5, 55.6, 64.7, 73.8, 82.9, 92. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Upon looking at the graph, the shape looks to be normal/symmetric distribution. The range starts at 37 and ends at 46, and it has outliers at 55 to 64, and from 82 to 92. The center has a mean between 37 and 46, since it’s a symmetric distribution the mode and median are all the same.

# %%
df['Masters'].describe()  #Change column name                       #this is for five-number summary
plt.hist(df['Masters'], edgecolor='k') #Change column name          #for histogram
# Out:
# (array([19.,  8., 27.,  2.,  2.,  2.,  0.,  2.,  0.,  4.]),
#  array([  1. ,  58.5, 116. , 173.5, 231. , 288.5, 346. , 403.5, 461. ,
#         518.5, 576. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Upon looking at the graph the shape looks to be right skewed ( positively skewd ). The range starts at 0 and ends between 300 and 400 , and has two outlier, one between 403 and 461, and the other between 518 and 576. The center has a mean between 231 and 288 and the mode is between 116 and 173, with the median being 288.5.

# %% [markdown]
# ## Question 3

# %% [markdown]
# Your next task is to choose three quantitative variables of your choice and two catagorical variables.
#
# Suppose you have chosen column 'Masters' as a quantiative and 'Gender_EN' for a categorical variable. Replicate the steps for task below.
#
# **3a.** Generate a grouped box plot to compare the
# distribution of Masters degree holders among male and female students. Describe your observations referring to the five-number-summaries of both genders.
#
# In the same way, do it for other quantitative and categorical variables. This should give rise to six cases.
#
# **3b.** Discuss any patterns you observe between male and female genders when you compare them.

# %% [markdown]
# **Answer 3a.**
#
# (Begin your answer by explicitly mentioning which three quantitative and two categorical variables you have chosen.)
#
# Case 1.

# %%
# Sample code to be used for Question 3
import pandas
import matplotlib.pyplot as plt
from numpy import percentile
df = pandas.read_csv(r'hamda almansoori.csv') #enter the path and name of your csv file
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip()

male=df[df["Gender_EN"]=='Male']            # For other categorical variable, change with their names
female=df[df["Gender_EN"]=='Female']        # For other categorical variable, change with their names

#create boxplots side by side
data1=male['Masters']    # Change column name
data2=female['Masters']  # Change column name
data = list([data1, data2])
fig, ax = plt.subplots()
ax.set_xticklabels(['Male', 'Female'])
plt.grid(axis="y")
plt.boxplot(data)
#descriptive statistics
print ("Descriptive Statistics for Male-Quantitative")
print(data1.describe())
print ("Descriptive Statistics for Female-Quantiative")
print(data2.describe())
# Out:
# <ipython-input-4-4f35a3bf0c74>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['Male', 'Female'])
# Descriptive Statistics for Male-Quantitative
# count     33.000000
# mean     162.090909
# std      177.621501
# min        1.000000
# 25%       45.000000
# 50%      132.000000
# 75%      132.000000
# max      576.000000
# Name: Masters, dtype: float64
# Descriptive Statistics for Female-Quantiative
# count     33.000000
# mean     117.727273
# std       84.648639
# min        1.000000
# 25%       57.000000
# 50%      132.000000
# 75%      132.000000
# max      332.000000
# Name: Masters, dtype: float64

# %% [markdown]
# The minimum score for both males and females is 1%. The lower quartile for males is 45%, while for the females is 57%. The median and upper quartile for males and females look to be the same at 132%. The maximum for males is 576%, unlike the females which is 332%. The interquartile range for outliers in males is 75%, and for females it is 75%. observing the whiskers for the males we can see the minimum whisker is very short, while the maximum cannot be seen. The whiskers on the female's box plot show that the minimum is also short but unlike the males, we can see a whisker on the maximum side which ends a little bit over 200. Both box plots look to be negativly skewed.The standard deviation for males is 177%, while for Females its shown to be 84%. The mean value for males is 162% and for the females, we can see it as 117%.

# %% [markdown]
# **Case 2.**

# %%
# Sample code to be used for Question 3
import pandas
import matplotlib.pyplot as plt
from numpy import percentile
df = pandas.read_csv(r'hamda almansoori.csv') #enter the path and name of your csv file
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip()

male=df[df["Gender_EN"]=='Male']            # For other categorical variable, change with their names
female=df[df["Gender_EN"]=='Female']        # For other categorical variable, change with their names

#create boxplots side by side
data1=male['Bachelors']    # Change column name
data2=female['Bachelors']  # Change column name
data = list([data1, data2])
fig, ax = plt.subplots()
ax.set_xticklabels(['Male', 'Female'])
plt.grid(axis="y")
plt.boxplot(data)
#descriptive statistics
print ("Descriptive Statistics for Male-Quantitative")
print(data1.describe())
print ("Descriptive Statistics for Female-Quantiative")
print(data2.describe())
# Out:
# <ipython-input-5-6978842996b1>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['Male', 'Female'])
# Descriptive Statistics for Male-Quantitative
# count      33.000000
# mean      294.121212
# std       448.335864
# min         1.000000
# 25%        23.000000
# 50%        99.000000
# 75%       356.000000
# max      1981.000000
# Name: Bachelors, dtype: float64
# Descriptive Statistics for Female-Quantiative
# count      33.000000
# mean      494.030303
# std       689.499841
# min         1.000000
# 25%        32.000000
# 50%       288.000000
# 75%       639.000000
# max      3527.000000
# Name: Bachelors, dtype: float64

# %% [markdown]
# The minimum score for both males and females is 1%. The lower quartile for males is 23%, while for the females is 32%. The median for males is 99%, and the females is 288%. upper quartile for males is 356% and females look to be 639%. The maximum for males is 1981%, unlike the females which is much higher at 3527%. The interquartile range for outliers in males is 333%, and for females it is 607%. observing the whiskers for the males we can see the minimum whisker is very short, while the maximum is much longer and ends between 500 and 1000. The whiskers on the female's box plot show that the minimum is also short similar to the males, we can see a whisker on the maximum side which ends slightly under 1500. The male box plot looks to be positively skewed, unlike the females which seems to be negatively skewed. The standard deviation for males is 448%, while for Females it’s shown to be 689%. The mean value for males is 294% and for the females, we can see it as 494%.

# %% [markdown]
# **Case 3.**

# %%
# Sample code to be used for Question 3
import pandas
import matplotlib.pyplot as plt
from numpy import percentile
df = pandas.read_csv(r'hamda almansoori.csv') #enter the path and name of your csv file
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip()

male=df[df["Gender_EN"]=='Male']            # For other categorical variable, change with their names
female=df[df["Gender_EN"]=='Female']        # For other categorical variable, change with their names

#create boxplots side by side
data1=male['Diploma']    # Change column name
data2=female['Diploma']  # Change column name
data = list([data1, data2])
fig, ax = plt.subplots()
ax.set_xticklabels(['Male', 'Female'])
plt.grid(axis="y")
plt.boxplot(data)
#descriptive statistics
print ("Descriptive Statistics for Male-Quantitative")
print(data1.describe())
print ("Descriptive Statistics for Female-Quantiative")
print(data2.describe())
# Out:
# <ipython-input-7-ae75c5b83f5c>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['Male', 'Female'])
# Descriptive Statistics for Male-Quantitative
# count     33.000000
# mean      40.878788
# std       29.069698
# min        1.000000
# 25%       14.000000
# 50%       55.000000
# 75%       55.000000
# max      119.000000
# Name: Diploma, dtype: float64
# Descriptive Statistics for Female-Quantiative
# count     33.000000
# mean      53.818182
# std       75.556458
# min        1.000000
# 25%        7.000000
# 50%       51.000000
# 75%       55.000000
# max      396.000000
# Name: Diploma, dtype: float64

# %% [markdown]
# **Case 4.**

# %%
# Sample code to be used for Question 3
import pandas
import matplotlib.pyplot as plt
from numpy import percentile
df = pandas.read_csv(r'hamda almansoori.csv') #enter the path and name of your csv file
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip()

male=df[df["LocalFlag_EN"]=='Local']            # For other categorical variable, change with their names
female=df[df["LocalFlag_EN"]=='Expat']        # For other categorical variable, change with their names

#create boxplots side by side
data1=male['Masters']    # Change column name
data2=female['Masters']  # Change column name
data = list([data1, data2])
fig, ax = plt.subplots()
ax.set_xticklabels(['Local', 'Expat'])
plt.grid(axis="y")
plt.boxplot(data)
#descriptive statistics
print ("Descriptive Statistics for Local-Quantitative")
print(data1.describe())
print ("Descriptive Statistics for Expat-Quantiative")
print(data2.describe())
# Out:
# <ipython-input-8-eba184726c95>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['Local', 'Expat'])
# Descriptive Statistics for Local-Quantitative
# count     33.000000
# mean     162.090909
# std      151.366146
# min        1.000000
# 25%       57.000000
# 50%      132.000000
# 75%      208.000000
# max      562.000000
# Name: Masters, dtype: float64
# Descriptive Statistics for Expat-Quantiative
# count     33.000000
# mean     117.727273
# std      125.710300
# min        1.000000
# 25%       57.000000
# 50%      132.000000
# 75%      132.000000
# max      576.000000
# Name: Masters, dtype: float64

# %% [markdown]
# **Case 5.**
#
# (Begin your answer by explicitly mentioning which three quantitative and two categorical variables you have chosen.)

# %%
# Sample code to be used for Question 3
import pandas
import matplotlib.pyplot as plt
from numpy import percentile
df = pandas.read_csv(r'hamda almansoori.csv') #enter the path and name of your csv file
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip()

male=df[df["LocalFlag_EN"]=='Local']            # For other categorical variable, change with their names
female=df[df["LocalFlag_EN"]=='Expat']        # For other categorical variable, change with their names

#create boxplots side by side
data1=male['Bachelors']    # Change column name
data2=female['Bachelors']  # Change column name
data = list([data1, data2])
fig, ax = plt.subplots()
ax.set_xticklabels(['Local', 'Expat'])
plt.grid(axis="y")
plt.boxplot(data)
#descriptive statistics
print ("Descriptive Statistics for Local-Quantitative")
print(data1.describe())
print ("Descriptive Statistics for Expat-Quantiative")
print(data2.describe())
# Out:
# Descriptive Statistics for Local-Quantitative
# count      33.000000
# mean      512.333333
# std       695.271605
# min         1.000000
# 25%        67.000000
# 50%       304.000000
# 75%       639.000000
# max      3527.000000
# Name: Bachelors, dtype: float64
# Descriptive Statistics for Expat-Quantiative
# count      33.000000
# mean      275.818182
# std       429.854587
# min         1.000000
# 25%         9.000000
# 50%        63.000000
# 75%       247.000000
# max      1554.000000
# Name: Bachelors, dtype: float64
# <ipython-input-9-4c6b904d0a89>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['Local', 'Expat'])

# %% [markdown]
# **Case 6.**

# %%
# Sample code to be used for Question 3
import pandas
import matplotlib.pyplot as plt
from numpy import percentile
df = pandas.read_csv(r'hamda almansoori.csv') #enter the path and name of your csv file
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip()

male=df[df["LocalFlag_EN"]=='Local']            # For other categorical variable, change with their names
female=df[df["LocalFlag_EN"]=='Expat']        # For other categorical variable, change with their names

#create boxplots side by side
data1=male['Diploma']    # Change column name
data2=female['Diploma']  # Change column name
data = list([data1, data2])
fig, ax = plt.subplots()
ax.set_xticklabels(['Local', 'Expat'])
plt.grid(axis="y")
plt.boxplot(data)
#descriptive statistics
print ("Descriptive Statistics for Local-Quantitative")
print(data1.describe())
print ("Descriptive Statistics for Expat-Quantiative")
print(data2.describe())
# Out:
# <ipython-input-10-46ed4be2594b>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['Local', 'Expat'])
# Descriptive Statistics for Local-Quantitative
# count     33.000000
# mean      53.424242
# std       76.223778
# min        1.000000
# 25%        9.000000
# 50%       33.000000
# 75%       55.000000
# max      396.000000
# Name: Diploma, dtype: float64
# Descriptive Statistics for Expat-Quantiative
# count     33.000000
# mean      41.272727
# std       27.458233
# min        1.000000
# 25%       14.000000
# 50%       55.000000
# 75%       55.000000
# max      119.000000
# Name: Diploma, dtype: float64

# %% [markdown]
# ## Question 4

# %% [markdown]
# In this task, you will work on the scatterplots to examine the relationship between dependent and independent variables. Treat 'Academic_Year' as an independent variable and use any of the two dependent variables you chose in Question 3 as the dependent variables.
#
# **4a.** Create separate scatterplots to examine the relationship between the dependent variables and the independent variable. Describe the scatterplots in terms of the form, strength, and direction of the relationships. Further examine if the relationship between the independent variable and each of the dependent variables varies by gender (you will need to create scatterplots separately for each gender to answer this question.)
#
# In the same way, do it for other quantitative variables. Now change the categorical variable and replicate calculations. This should give rise to ten cases.
#
# **4b.** Explain in simple words what you observed by reporting your findings.

# %% [markdown]
# **Answer 4a.**
#
# (Begin your answer by explicitly mentioning which three quantitative and two categorical variables you have chosen.)
#
# **Case 1.**

# %%
# Sample code for Question 4:
import pandas
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as statsmodels
df = pandas.read_csv(r'hamda almansoori.csv') #enter the path and name of your csv file
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip()


#display the correlation coefficient
corr=stats.stats.pearsonr(df["Bachelors"],df['Academic_Year'])[0]
print("correlation coefficient=", corr)

#display the scatterplot
plt.scatter(df['Academic_Year'],df["Bachelors"])  # Change column name
plt.title ("Column A vs Column B") # Change column name
plt.xlabel("Column A")
plt.ylabel("Column B")
plt.show()
# Out:
# <ipython-input-20-ee9c61af362c>:14: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   corr=stats.stats.pearsonr(df["Bachelors"],df['Academic_Year'])[0]
# correlation coefficient= 0.11921066669590254

# %% [markdown]
# **Case 2.**

# %%
#Q4 - Categories included - Further examine if the relationship between the independent variable and
#each of the dependent variables varies by gender (you will need to create scatterplots separately for each gender to answer this question.)
# Sample code for Question 4 - for male category: Masters(male) Vs Academic Year - General Code
#Please change the column names and category according to your requirements

import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Read the CSV file (replace '/Path.csv' with your file path)
df = pd.read_csv(r'hamda almansoori.csv')

# clean the column names
df.columns = df.columns.str.strip()

# specify the column names for the variables
independent_variable = "Academic_Year"  # change this to your independent variable
dependent_variable = "Bachelors"  # change this to your dependent variable
categorical_variable = "Gender_EN"  # change this to your categorical variable
category_to_show = "Male"  # change this to the category you want to show

# filter the DataFrame for the specified category
category_data = df[df[categorical_variable] == category_to_show]

# calculate the correlation coefficient for the specified category
corr_category = stats.pearsonr(category_data[independent_variable], category_data[dependent_variable])[0]

# print the correlation coefficient
print(f"Correlation coefficient ({category_to_show}) = {corr_category}")

# create a scatterplot for the specified category
plt.scatter(category_data[independent_variable], category_data[dependent_variable])
plt.title(f"{independent_variable} vs {dependent_variable} ({category_to_show})")
plt.xlabel(independent_variable)
plt.ylabel(dependent_variable)
plt.show()
# Out:
# Correlation coefficient (Male) = -0.0663446289674497

# %% [markdown]
# **Case 3.**

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Read the CSV file (replace '/Path.csv' with your file path)
df = pd.read_csv(r'hamda almansoori.csv')

# clean the column names
df.columns = df.columns.str.strip()

# specify the column names for the variables
independent_variable = "Academic_Year"  # change this to your independent variable
dependent_variable = "Bachelors"  # change this to your dependent variable
categorical_variable = "Gender_EN"  # change this to your categorical variable
category_to_show = "Female"  # change this to the category you want to show

# filter the DataFrame for the specified category
category_data = df[df[categorical_variable] == category_to_show]

# calculate the correlation coefficient for the specified category
corr_category = stats.pearsonr(category_data[independent_variable], category_data[dependent_variable])[0]

# print the correlation coefficient
print(f"Correlation coefficient ({category_to_show}) = {corr_category}")

# create a scatterplot for the specified category
plt.scatter(category_data[independent_variable], category_data[dependent_variable])
plt.title(f"{independent_variable} vs {dependent_variable} ({category_to_show})")
plt.xlabel(independent_variable)
plt.ylabel(dependent_variable)
plt.show()
# Out:
# Correlation coefficient (Female) = 0.21637345125257992

# %% [markdown]
# **Case 4.**

# %%
# Case 4. Code Here.
# Sample code for Question 4:
import pandas
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as statsmodels
df = pandas.read_csv(r'hamda almansoori.csv') #enter the path and name of your csv file
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip()


#display the correlation coefficient
corr=stats.stats.pearsonr(df["Masters"],df['Academic_Year'])[0]
print("correlation coefficient=", corr)

#display the scatterplot
plt.scatter(df['Academic_Year'],df["Masters"])  # Change column name
plt.title ("Column A vs Column B") # Change column name
plt.xlabel("Column A")
plt.ylabel("Column B")
plt.show()
# Out:
# <ipython-input-12-7c98902fc756>:15: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   corr=stats.stats.pearsonr(df["Masters"],df['Academic_Year'])[0]
# correlation coefficient= -0.022791300793665484

# %% [markdown]
# **Case 5.**

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Read the CSV file (replace '/Path.csv' with your file path)
df = pd.read_csv(r'hamda almansoori.csv')

# clean the column names
df.columns = df.columns.str.strip()

# specify the column names for the variables
independent_variable = "Academic_Year"  # change this to your independent variable
dependent_variable = "Masters"  # change this to your dependent variable
categorical_variable = "Gender_EN"  # change this to your categorical variable
category_to_show = "Male"  # change this to the category you want to show

# filter the DataFrame for the specified category
category_data = df[df[categorical_variable] == category_to_show]

# calculate the correlation coefficient for the specified category
corr_category = stats.pearsonr(category_data[independent_variable], category_data[dependent_variable])[0]

# print the correlation coefficient
print(f"Correlation coefficient ({category_to_show}) = {corr_category}")

# create a scatterplot for the specified category
plt.scatter(category_data[independent_variable], category_data[dependent_variable])
plt.title(f"{independent_variable} vs {dependent_variable} ({category_to_show})")
plt.xlabel(independent_variable)
plt.ylabel(dependent_variable)
plt.show()

# %% [markdown]
# **Case 6.**

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Read the CSV file (replace '/Path.csv' with your file path)
df = pd.read_csv(r'hamda almansoori.csv')

# clean the column names
df.columns = df.columns.str.strip()

# specify the column names for the variables
independent_variable = "Academic_Year"  # change this to your independent variable
dependent_variable = "Masters"  # change this to your dependent variable
categorical_variable = "Gender_EN"  # change this to your categorical variable
category_to_show = "Female"  # change this to the category you want to show

# filter the DataFrame for the specified category
category_data = df[df[categorical_variable] == category_to_show]

# calculate the correlation coefficient for the specified category
corr_category = stats.pearsonr(category_data[independent_variable], category_data[dependent_variable])[0]

# print the correlation coefficient
print(f"Correlation coefficient ({category_to_show}) = {corr_category}")

# create a scatterplot for the specified category
plt.scatter(category_data[independent_variable], category_data[dependent_variable])
plt.title(f"{independent_variable} vs {dependent_variable} ({category_to_show})")
plt.xlabel(independent_variable)
plt.ylabel(dependent_variable)
plt.show()
# Out:
# Correlation coefficient (Female) = -0.009661987164857694

# %% [markdown]
# case 7

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Read the CSV file (replace '/Path.csv' with your file path)
df = pd.read_csv(r'hamda almansoori.csv')

# clean the column names
df.columns = df.columns.str.strip()

# specify the column names for the variables
independent_variable = "Academic_Year"  # change this to your independent variable
dependent_variable = "Bachelors"  # change this to your dependent variable
categorical_variable = "Gender_EN"  # change this to your categorical variable
category_to_show = "Local"  # change this to the category you want to show

# filter the DataFrame for the specified category
category_data = df[df[categorical_variable] == category_to_show]

# calculate the correlation coefficient for the specified category
corr_category = stats.pearsonr(category_data[independent_variable], category_data[dependent_variable])[0]

# print the correlation coefficient
print(f"Correlation coefficient ({category_to_show}) = {corr_category}")

# create a scatterplot for the specified category
plt.scatter(category_data[independent_variable], category_data[dependent_variable])
plt.title(f"{independent_variable} vs {dependent_variable} ({category_to_show})")
plt.xlabel(independent_variable)
plt.ylabel(dependent_variable)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-8282266a4ca2> in <cell line: 23>()
#      21
#      22 # calculate the correlation coefficient for the specified category
# ---> 23 corr_category = stats.pearsonr(category_data[independent_variable], category_data[dependent_variable])[0]
#      24
#      25 # print the correlation coefficient
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in pearsonr(x, y, alternative, method)
#    4766
#    4767     if n < 2:
# -> 4768         raise ValueError('x and y must have length at least 2.')
#    4769
#    4770     x = np.asarray(x)
#
# ValueError: x and y must have length at least 2.

# %% [markdown]
# **Answer 4b.**

# %% [markdown]
# ## Question 5

# %% [markdown]
# You will now work on the simple linear regression model that predicts for the dependent variable. Treat 'Academic_Year' as an independent variable and use any of the two dependent variables you chose in Questions 3 as the dependent variables.
#
# **5a.** Fit a simple linear regression model between your dependent and independent variables. Generate and use the residual plot, the standard error, and the R^2 to assess the fit of each linear model. If the model is a good fit, interpret the slope and the intercept.
#
# In the same way, do it for other quantitative variables. Now change the categorical variable and replicate calculations. This should give rise to ten cases.
#
# **5b.** Summarize and present your findings in a sophisticated statistical terms.

# %% [markdown]
# **Answer 5a.**
#
# (Begin your answer by explicitly mentioning which three quantitative and two categorical variables you have chosen.)
#
# **Case 1.**

# %% [markdown]
# case 2

# %%
#Q5 - Categories included - Now change the categorical variable and replicate calculations.
## Bachelors (Male) vs Academic_Year - General Code
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# read the CSV file (replace '/Pathname.csv' with your file path)
df = pd.read_csv(r'hamda almansoori.csv')

# clean the column names
df.columns = df.columns.str.strip()

# specify the column names for the variables
independent_variable = "Academic_Year"  # change this to your independent variable
dependent_variable = "Bachelors"  # change this to your dependent variable
categorical_variable = "Gender_EN"  # Change this to your categorical variable
category_to_show = "Male"  # change this to the category you want to show

# Filter the DataFrame for the specified category
category_data = df[df[categorical_variable] == category_to_show]

def regression_equation(column_x, column_y):
    # fit the regression line using "statsmodels" library:
    X = category_data[independent_variable]
    X = sm.add_constant(X)
    Y = category_data[column_y]
    regressionmodel = sm.OLS(Y, X).fit()  # OLS stands for "ordinary least squares"
    print('R2: ', round(regressionmodel.rsquared, 3))
    SE = np.sqrt(regressionmodel.mse_resid)
    print('SE=', round(SE, 3))

    # display the correlation coefficient
    correlation_coefficient = stats.pearsonr(category_data[independent_variable], Y)[0]
    print("correlation_coefficient=", round(correlation_coefficient, 3))

    # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
    slope = round(regressionmodel.params[1], 3)
    intercept = round(regressionmodel.params[0], 3)
    print("Regression equation: " + column_y + " = ", slope, "* " + column_x + " + ", intercept)

    # display the scatter plot with the line of best fit
    plt.scatter(category_data[independent_variable], Y, color='green')
    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.title("Scatterplot: " + column_y + " vs " + column_x + " (" + category_to_show + ")")
    plt.plot(category_data[independent_variable], regressionmodel.params[1] * category_data[independent_variable] + regressionmodel.params[0], color='red')
    plt.show()
    # display the residual plot
    sns.residplot(x=column_x,
                  y=column_y,
                  data=category_data)
    plt.show()
    # display the residual plot with SE
    sns.residplot(x=column_x,
                  y=column_y,
                  data=category_data)
    plt.axhline(y=SE, color='r', linestyle='--')
    plt.axhline(y=-SE, color='r', linestyle='--')
    plt.show()

regression_equation(independent_variable, dependent_variable)
# Out:
# R2:  0.004
# SE= 454.506
# correlation_coefficient= -0.066
# Regression equation: Bachelors =  -13.212 * Academic_Year +  26949.626

# %% [markdown]
# case 3

# %%
#Q5 - Categories included - Now change the categorical variable and replicate calculations.
## Bachelors (Female) vs Academic_Year - General Code
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# read the CSV file (replace '/Pathname.csv' with your file path)
df = pd.read_csv(r'hamda almansoori.csv')

# clean the column names
df.columns = df.columns.str.strip()

# specify the column names for the variables
independent_variable = "Academic_Year"  # change this to your independent variable
dependent_variable = "Bachelors"  # change this to your dependent variable
categorical_variable = "Gender_EN"  # Change this to your categorical variable
category_to_show = "Female"  # change this to the category you want to show

# Filter the DataFrame for the specified category
category_data = df[df[categorical_variable] == category_to_show]

def regression_equation(column_x, column_y):
    # fit the regression line using "statsmodels" library:
    X = category_data[independent_variable]
    X = sm.add_constant(X)
    Y = category_data[column_y]
    regressionmodel = sm.OLS(Y, X).fit()  # OLS stands for "ordinary least squares"
    print('R2: ', round(regressionmodel.rsquared, 3))
    SE = np.sqrt(regressionmodel.mse_resid)
    print('SE=', round(SE, 3))

    # display the correlation coefficient
    correlation_coefficient = stats.pearsonr(category_data[independent_variable], Y)[0]
    print("correlation_coefficient=", round(correlation_coefficient, 3))

    # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
    slope = round(regressionmodel.params[1], 3)
    intercept = round(regressionmodel.params[0], 3)
    print("Regression equation: " + column_y + " = ", slope, "* " + column_x + " + ", intercept)

    # display the scatter plot with the line of best fit
    plt.scatter(category_data[independent_variable], Y, color='green')
    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.title("Scatterplot: " + column_y + " vs " + column_x + " (" + category_to_show + ")")
    plt.plot(category_data[independent_variable], regressionmodel.params[1] * category_data[independent_variable] + regressionmodel.params[0], color='red')
    plt.show()
    # display the residual plot
    sns.residplot(x=column_x,
                  y=column_y,
                  data=category_data)
    plt.show()
    # display the residual plot with SE
    sns.residplot(x=column_x,
                  y=column_y,
                  data=category_data)
    plt.axhline(y=SE, color='r', linestyle='--')
    plt.axhline(y=-SE, color='r', linestyle='--')
    plt.show()

regression_equation(independent_variable, dependent_variable)
# Out:
# R2:  0.047
# SE= 683.937
# correlation_coefficient= 0.216
# Regression equation: Bachelors =  52.315 * Academic_Year +  -105050.168

# %% [markdown]
# case 4

# %% [markdown]
# **Case 5.**

# %%
#Q5 - Categories included - Now change the categorical variable and replicate calculations.
## Master (Male) vs Academic_Year - General Code
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# read the CSV file (replace '/Pathname.csv' with your file path)
df = pd.read_csv(r'hamda almansoori.csv')

# clean the column names
df.columns = df.columns.str.strip()

# specify the column names for the variables
independent_variable = "Academic_Year"  # change this to your independent variable
dependent_variable = "Masters"  # change this to your dependent variable
categorical_variable = "Gender_EN"  # Change this to your categorical variable
category_to_show = "Male"  # change this to the category you want to show

# Filter the DataFrame for the specified category
category_data = df[df[categorical_variable] == category_to_show]

def regression_equation(column_x, column_y):
    # fit the regression line using "statsmodels" library:
    X = category_data[independent_variable]
    X = sm.add_constant(X)
    Y = category_data[column_y]
    regressionmodel = sm.OLS(Y, X).fit()  # OLS stands for "ordinary least squares"
    print('R2: ', round(regressionmodel.rsquared, 3))
    SE = np.sqrt(regressionmodel.mse_resid)
    print('SE=', round(SE, 3))

    # display the correlation coefficient
    correlation_coefficient = stats.pearsonr(category_data[independent_variable], Y)[0]
    print("correlation_coefficient=", round(correlation_coefficient, 3))

    # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
    slope = round(regressionmodel.params[1], 3)
    intercept = round(regressionmodel.params[0], 3)
    print("Regression equation: " + column_y + " = ", slope, "* " + column_x + " + ", intercept)

    # display the scatter plot with the line of best fit
    plt.scatter(category_data[independent_variable], Y, color='green')
    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.title("Scatterplot: " + column_y + " vs " + column_x + " (" + category_to_show + ")")
    plt.plot(category_data[independent_variable], regressionmodel.params[1] * category_data[independent_variable] + regressionmodel.params[0], color='red')
    plt.show()
    # display the residual plot
    sns.residplot(x=column_x,
                  y=column_y,
                  data=category_data)
    plt.show()
    # display the residual plot with SE
    sns.residplot(x=column_x,
                  y=column_y,
                  data=category_data)
    plt.axhline(y=SE, color='r', linestyle='--')
    plt.axhline(y=-SE, color='r', linestyle='--')
    plt.show()

regression_equation(independent_variable, dependent_variable)

# %% [markdown]
# **Case 6.**

# %%
#Q5 - Categories included - Now change the categorical variable and replicate calculations.
## Master (female) vs Academic_Year - General Code
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# read the CSV file (replace '/Pathname.csv' with your file path)
df = pd.read_csv(r'hamda almansoori.csv')

# clean the column names
df.columns = df.columns.str.strip()

# specify the column names for the variables
independent_variable = "Academic_Year"  # change this to your independent variable
dependent_variable = "Masters"  # change this to your dependent variable
categorical_variable = "Gender_EN"  # Change this to your categorical variable
category_to_show = "Female"  # change this to the category you want to show

# Filter the DataFrame for the specified category
category_data = df[df[categorical_variable] == category_to_show]

def regression_equation(column_x, column_y):
    # fit the regression line using "statsmodels" library:
    X = category_data[independent_variable]
    X = sm.add_constant(X)
    Y = category_data[column_y]
    regressionmodel = sm.OLS(Y, X).fit()  # OLS stands for "ordinary least squares"
    print('R2: ', round(regressionmodel.rsquared, 3))
    SE = np.sqrt(regressionmodel.mse_resid)
    print('SE=', round(SE, 3))

    # display the correlation coefficient
    correlation_coefficient = stats.pearsonr(category_data[independent_variable], Y)[0]
    print("correlation_coefficient=", round(correlation_coefficient, 3))

    # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
    slope = round(regressionmodel.params[1], 3)
    intercept = round(regressionmodel.params[0], 3)
    print("Regression equation: " + column_y + " = ", slope, "* " + column_x + " + ", intercept)

    # display the scatter plot with the line of best fit
    plt.scatter(category_data[independent_variable], Y, color='green')
    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.title("Scatterplot: " + column_y + " vs " + column_x + " (" + category_to_show + ")")
    plt.plot(category_data[independent_variable], regressionmodel.params[1] * category_data[independent_variable] + regressionmodel.params[0], color='red')
    plt.show()
    # display the residual plot
    sns.residplot(x=column_x,
                  y=column_y,
                  data=category_data)
    plt.show()
    # display the residual plot with SE
    sns.residplot(x=column_x,
                  y=column_y,
                  data=category_data)
    plt.axhline(y=SE, color='r', linestyle='--')
    plt.axhline(y=-SE, color='r', linestyle='--')
    plt.show()

regression_equation(independent_variable, dependent_variable)
# Out:
# R2:  0.0
# SE= 85.999
# correlation_coefficient= -0.01
# Regression equation: Masters =  -0.287 * Academic_Year +  696.333

# %%
# Sample code for Question 5:
import pandas
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as statsmodels
import seaborn as sns

df = pandas.read_csv(r'hamda almansoori.csv') #enter the path and name of your csv file
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip()

def regression_equation(column_x, column_y):
    # fit the regression line using "statsmodels" library:
    X= df['Academic_Year']   # Change column name
    X = statsmodels.add_constant(X)
    Y = df['Bachelors'] # Change column name
    regressionmodel = statsmodels.OLS(Y,X).fit() #OLS stands for "ordinary least squares"
    print('R2: ', round(regressionmodel.rsquared, 3))
    SE=np.sqrt(regressionmodel.mse_resid)
    print ('SE=', round(SE, 3))

     #display the correlation coefficient
    correlation_coefficient=stats.stats.pearsonr(df['Academic_Year'],Y)[0]
    print("correlation_coefficient=", round(correlation_coefficient,3))

    # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
    slope = round(regressionmodel.params[1],3)
    intercept = round(regressionmodel.params[0],3)
    print("Regression equation: "+column_y+" = ",slope,"* "+column_x+" + ",intercept)

    #display the scatter plot with the line of best fit
    plt.scatter(df['Academic_Year'], Y, color='green')
    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.plot(df[column_x], regressionmodel.params[1]*df[column_x]+regressionmodel.params[0], color='red')
    plt.show()
    #display the residual plot
    sns.residplot(x = column_x, y = column_y, data = df)
    plt.show()
    #display the residual plot with SE
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.axhline(y=SE, color='r', linestyle='--')
    plt.axhline(y=-SE, color='r', linestyle='--')
    plt.show()
regression_equation('Academic_Year', '???')    # Change column name
# Out:
# R2:  0.014
# SE= 586.138
# correlation_coefficient= 0.119
# Regression equation: ??? =  27.392 * Academic_Year +  -54869.369
# <ipython-input-22-edff3d96b2d6>:25: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   correlation_coefficient=stats.stats.pearsonr(df['Academic_Year'],Y)[0]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %% [markdown]
# ## Question 6

# %% [markdown]
# The conservation and rehabilitation of local flora and natural habitats comes under part of the biodiversity program of Environment Agency, Abu Dhabi (EAD). A sophisticated and high-tech monitoring system provides the following annual production of plants within native plant nursery. The number of floras in a particular year is written on top of that column which may be used  in calculations.
#
# ![BD.jpg](attachment:BD.jpg)
#
# Answer the following questions.

# %% [markdown]
# **6a.** Calculate the percentage increase in plants products from year Y1 to year Y2, where both years Y1 and Y2 are obtained by running the code below.

# %%
# Run this code which will provide you the years for which you need to work
import random
t=random.randint(2014, 2018)
s=random.randint(2019, 2022)
print("From Y1=", t, "to  Y2 =", s)
# Out:
# From Y1= 2014 to  Y2 = 2022

# %% [markdown]
# **Provide your answer here.**
#
# **Answer 6a:** Percentage Increase = 69.6 %

# %% [markdown]
# **6b.** Which two years the percentage increase in the annual production of plants was equal to P%? where P is to be found by running the code below and it is calculated up to one decimal place.

# %%
# Run this code to get the percentage
t=random.choice([5.9,13.3,62.3,5.7,8.6,31.6,12, 20, 83.9, 71.6, 14.8, 42.9, 94.7,94.4, 86.3])
print("Percentage = P% =", t, "%")
# Out:
# Percentage = P% = 86.3 %

# %% [markdown]
# **Provide your answer here.**
#
# **Answer 6b:** Year______ to Year_____

# %% [markdown]
# ## Question 7

# %% [markdown]
# Under the long-term marine water quality monitoring program of the Environment Agency Abu Dhabi (EAD), a red tide monitoring project was launched to look for harmful algal blooms (HAB) in marine water. The project accounted for number of such HAB incidents in Abu Dhabi from 2002 to 2022. Use your statistical skills of this course IDS-103, to make two strong observations (non-trivial) to be reported to EAD from the graph below.
#
# ![BD2.jpg](attachment:BD2.jpg)

# %% [markdown]
# **Answer 7:**
